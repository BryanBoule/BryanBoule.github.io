# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load train data
xls = pd.ExcelFile("WHR2018Chapter2OnlineData.xls")

sheet1 = xls.parse(0)
sheet2 = xls.parse(1)
sheet3 = xls.parse(2)
sheet4 = xls.parse(3)
sheet5 = xls.parse(4)

# %%
sheet2.columns
# Out:
# Index(['Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.92) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sheet2 = sheet2.drop(['Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
       'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23'], axis=1)

# %%
sheet1.head()
# Out:
#        country  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         49.209663                      0.718114    0.181819
# 1                         49.624432                      0.678896    0.203614
# 2                         50.008961                      0.600127    0.137630
# 3                         50.367298                      0.495901    0.175329
# 4                         50.709263                      0.530935    0.247159
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %%
sheet2.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low  \
# 0      Finland           7.6321      7.694913     7.569287
# 1       Norway           7.5937      7.657077     7.530323
# 2      Denmark           7.5553      7.623292     7.487309
# 3      Iceland           7.4952      7.592534     7.397867
# 4  Switzerland           7.4873      7.569994     7.404606
#
#    Dystopia (1.92) + residual  Explained by: GDP per capita  \
# 0                    2.595186                      1.305095
# 1                    2.383242                      1.455627
# 2                    2.370179                      1.351153
# 3                    2.425990                      1.343301
# 4                    2.319529                      1.419727
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.592134                               0.874454
# 1                      1.582340                               0.860763
# ...

# %%
sheet3.head()
# Out:
#         Country  Changes in happiness scores  Whisker-high  Whisker-low
# 0          Togo                     1.190646      1.381097     1.000195
# 1        Latvia                     1.026396      1.168365     0.884426
# 2      Bulgaria                     1.020848      1.155436     0.886261
# 3  Sierra Leone                     1.005667      1.190998     0.820337
# 4        Serbia                     0.977625      1.122019     0.833231

# %%
sheet4.head()
# Out:
#        Country  Average happiness of foreign born  Whisker-high  Whisker-low  \
# 0      Finland                           7.662304      7.885813     7.438794
# 1      Denmark                           7.546741      7.720045     7.373437
# 2       Norway                           7.434961      7.690867     7.179054
# 3      Iceland                           7.426854      7.781937     7.071771
# 4  New Zealand                           7.286391      7.370615     7.202168
#
#    Average happiness of locally born
# 0                           7.498114
# 1                           7.705683
# 2                           7.601207
# 3                           7.438337
# 4                           7.326226

# %%
sheet5.head()
# Out:
#        country              Region indicator  Life ladder, 2015-2017  \
# 0  Afghanistan                    South Asia                3.631519
# 1      Albania    Central and Eastern Europe                4.586040
# 2      Algeria  Middle East and North Africa                5.294638
# 3       Angola            Sub-Saharan Africa                3.794838
# 4    Argentina   Latin America and Caribbean                6.387958
#
#    Standard error, life ladder, 2015-2017  Log of GDP per person, 2015-2017  \
# 0                                0.042360                          7.462610
# 1                                0.055813                          9.338126
# 2                                0.057087                          9.540703
# 3                                0.079919                          8.741957
# 4                                0.049497                          9.842001
#
#    GDP per person, 2015-2017  Healthy life expectancy, 2015-2017  \
# ...

# %%
# load train data
df_2015 = pd.read_csv(filepath_or_buffer = '2015.csv', 
                       engine = 'c')

df_2016 = pd.read_csv(filepath_or_buffer = '2016.csv', 
                       engine = 'c')

df_2017 = pd.read_csv(filepath_or_buffer = '2017.csv', 
                       engine = 'c')

# %%
df_2015.sort_values(by = 'Economy (GDP per Capita)', ascending=False)
# Out:
#                       Country                           Region  \
# 27                      Qatar  Middle East and Northern Africa
# 16                 Luxembourg                   Western Europe
# 38                     Kuwait  Middle East and Northern Africa
# 23                  Singapore                Southeastern Asia
# 3                      Norway                   Western Europe
# 19       United Arab Emirates  Middle East and Northern Africa
# 0                 Switzerland                   Western Europe
# 34               Saudi Arabia  Middle East and Northern Africa
# 14              United States                    North America
# 71                  Hong Kong                     Eastern Asia
# 21                       Oman  Middle East and Northern Africa
# 12                    Austria                   Western Europe
# 17                    Ireland                   Western Europe
# 9                   Australia        Australia and New Zealand
# ...

# %%
cor = df_2015.corr()
#high_corr = (corr >= 0.8).astype('uint8')
plt.figure(figsize=(10,10))
sns.heatmap(cor, cmap='RdBu_r', annot=True, center=0.0)
plt.show()

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2016.sort_values(by = 'Dystopia Residual', ascending=False)
# Out:
#                 Country                           Region  Happiness Rank  \
# 75              Somalia               Sub-Saharan Africa              76
# 20               Mexico      Latin America and Caribbean              21
# 16               Brazil      Latin America and Caribbean              17
# 37              Algeria  Middle East and Northern Africa              38
# 54              Moldova       Central and Eastern Europe              55
# 13           Costa Rica      Latin America and Caribbean              14
# 10               Israel  Middle East and Northern Africa              11
# 45          El Salvador      Latin America and Caribbean              46
# 38            Guatemala      Latin America and Caribbean              39
# 91             Pakistan                    Southern Asia              92
# 30             Colombia      Latin America and Caribbean              31
# 25            Argentina      Latin America and Caribbean              26
# ...

# %%
df_2017.sort_values(by = 'Trust..Government.Corruption.', ascending=False )
# Out:
#                      Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 25                 Singapore              26            6.572      6.636723
# 150                   Rwanda             151            3.471      3.543030
# 34                     Qatar              35            6.375      6.568477
# 1                    Denmark               2            7.522      7.581728
# 8                     Sweden               9            7.284      7.344095
# 7                New Zealand               8            7.314      7.379510
# 4                    Finland               5            7.469      7.527542
# 3                Switzerland               4            7.494      7.561772
# 20      United Arab Emirates              21            6.648      6.722047
# 17                Luxembourg              18            6.863      6.923686
# 0                     Norway               1            7.537      7.594445
# ...
